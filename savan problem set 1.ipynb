# %% [markdown]
# # Question 1
# what data type is each of the following?

# %%
5 : integer
5.0 : float
5>1 : boolean
'5' : character
5*2 : integer
'5'*2 : string
'5'+'2': string
5/2 : float
5%2 : float
{5,2,1} : array
5 == 3 : boolean
Pi(the number) : double

# %% [markdown]
# # Question 2
# Write (and evaluate) C# expressions that answer these questions:
# a. How many letters are there in 'Supercalifragilisticexpialidocious'?
# b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
# c. Which of the following words is the longest:
# Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
# Bababadalgharaghtakamminarronnkonn?
# d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
# 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

# %% [markdown]
# # question 2(A)

# %%
string var = "Supercalifragilisticexpialidocious";
int number=0;
             
   for(int i=0; i<var.Length; i++) 
     {
        number++;
      }
             
Console.WriteLine(number);
Console.Read();
# Out:
# 34

# %% [markdown]
# # Question 2(B)

# %%
string var1 = "Supercalifragilisticexpialidocious";
string var2 = "ice";

Console.WriteLine(var1.Contains(var2));
Console.ReadLine();
# Out:
# True

# %% [markdown]
# # Question 2(c)

# %%
string[] words = {"Supercalifragilisticexpialidocious","Honorificabilitudinitatibus","Bababadalgharaghtakamminarronnkonn"};
             
            String w1="";
            int c1=0;
            foreach(string count in words)
              {
                if(count.Length > c1 )
                 {
                   w1 = count;
                   c1 = count.Length;
                 }
              }
              
             Console.WriteLine(w1);
             Console.ReadLine();
# Out:
# Supercalifragilisticexpialidocious

# %% [markdown]
# # Question 2(D)

# %%
string[] spells =new string[] {"Berlioz", "Borodin", "Brian", "Bartok","Bellini", "Buxtehude", "Bernstein"};

Array.Sort(spells);

foreach (string word in spells)
{
    Console.Write(word+ " ,");
}
Console.WriteLine();
# Out:
# Bartok ,Bellini ,Berlioz ,Bernstein ,Borodin ,Brian ,Buxtehude ,

# %% [markdown]
# # Question 3
# Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
# sides of a triangle and returns the area of the triangle. By Heron's formula, the area
# of a triangle with side lengths a, b, and c is
# s(s - a)(s -b)(s -c)
# , where
# s = (a+b+c)/2.

# %%
double a=2,b=2,c=2;



s = (a+b+c)/2;
area = Math.Sqrt(s*(s - a)*(s - b)*(s - c));
Console.WriteLine("Area = {0}",area);
Console.ReadLine();
# Out:
# Area = 1.7320508075688772

# %% [markdown]
# # Question 4

# %%
# Write a program in C# Sharp to separate odd and even integers in separate arrays.

# %%
using System;
public class OddEven
{
    public static void Main()
    {
int[] arr1 = new int[10];
int[] arr2 = new int[10];
int[] arr3 = new int[10];
int a, b = 0 ,c = 0, d ;

Console.Write("Input the number of elements to be stored in the array");
d=Convert.ToInt32(Console.ReadLine());

Console.Write("Input{0} element in the array = ");
for(a=0;a<d;a++)
{
    Console.Write("element - {0}=",a);
    arr1[a] = Convert.ToInt32(Console.ReadLine());
    
}

for (a=0;a<d;a++)
{
    if(arr1[a]%2 == 0)
    {
        arr2[b] == arr1[a];
        b++;
    }
    else
    {
        arr3[c]=arr1[a];
        c++;
        
    }
}

Console.Write("The even numbers are: \n");
for(a=0;a<c;a++)
{
    Console.Write("{0} ", arr2[a]);
}

Console.Write("The even numbers are: \n");
for(a=0;a<c;a++)
{
    Console.Write("{0} ", arr3[a]);
}
Console.Write("\n");
    }
}
# Out:
# (26,9): error CS0201: Only assignment, call, increment, decrement, await, and new object expressions can be used as a statement
# Cell not executed: compilation error

# %% [markdown]
# # Question 5

# %%
using System;
using System.Collections.Generic;
using System.Linq;
using System.Text;

namespace consoleapp
{
  class csharp
  {
    if(x > x1 && x < x2 && y > y1 && y < y2)
       return true;
    return false;   
  }
  
  static void Main(string[] args)
  {
   
   Console.Write(" x: ");
   double x = Convert.ToDouble(Console.ReadLIne());
   Console.Write(" x1: ");
   double x1 = Convert.ToDouble(Console.ReadLIne());
   Console.Write(" x2: ");
   double x2 = Convert.ToDouble(Console.ReadLIne());
   Console.Write(" y: ");
   double y = Convert.ToDouble(Console.ReadLIne());
   Console.Write(" y1: ");
   double y1 = Convert.ToDouble(Console.ReadLIne());
   Console.Write(" y2: ");
   double y2 = Convert.ToDouble(Console.ReadLIne());
  }
   
   if(inside(x,y,x1,y1,x2,y2)) 
     Console.Write("true");
   else
     Console.Write("false");
   
  }
}

# %% [markdown]
# # Question 6 python

# %%
A1 = 'ay'
B1 = 'way'

consonant = ('B','C','D','F','G','H','J','K','L','M','N','P','Q','R','S','T','V','W','X','Y','Z')
VOWEL = ('A','E','I','O','U')

char1 = input("enter the word:")
stock = char1[0]
stock = str(stock)
stock = stock.upper()

if stock in consonant:
        print(stock,"it is consonant")
        length_stock = len(char1)
        remove_stock = char1[1:length_stock]
        pig_latin = remove_stock + stock + A1
        print("the word is ",pig_latin)
elif word in vowel:
        print(stock,"it is vovel")
        pig_latin = char1 + B1
        print("the word is",pig_latin)
else:
    print("No word found")
# Out:
# enter the word:saaa
# S it is consonant
# the word is  aaaSay

# %% [markdown]
# # Question 7

# %%
def bldcount(bloodtype1):

    infile=open("bloodtype1.txt", 'r')
    content= infile.read('r')
    infile.close() 
    content = content.split() 
    return len(content)
    
for i in bloodtype1:
    
if content.count(i)==0:
    print('There are no patients of blood type',i+'.')
elif content.count(i)==1:
    print('There is 1 patient of blood type',i+'.')
else:
    print('There are',content.count(i),'patients of blood type', i+'.')

# %% [markdown]
# # Question 8

# %%
def cur(name,money):
    with open("currencies.txt")as x:
     for num,currency in enumerate(x,1):
            if name in currency:
                data=list(line.split())
                print(double(money) * double(data[1]))

name = input("Unit Of Currency:-")
money = input("Enter The Amount:-")
curconv(name,money)

# %% [markdown]
# # Question 9

# %% [markdown]
# Trying to add incompatible variables, as in adding 6 + ‘a’
# Answer: TypeError
#
# Referring to the 12th item of a list that has only 10 items
# Answer: IndexError
#
# using a value that is out of range for a function’s input, such as calling math.sqrt(-1.0)
# Answer: ValueError
#
# Using an undeclared variable, such as print(x) when x has not been defined
# Answer: NameError
#
# Trying to open a file that does not exist, such as mistyping the file name or looking in the wrong directory
# Answer: FileNotFoundError

# %% [markdown]
# # Question 10

# %%
line1 = input("Enter the string")

def f(line1):
    str1= user_str.split()
    x={}
    
    for i in str1:
        print(x)
f(line1)
